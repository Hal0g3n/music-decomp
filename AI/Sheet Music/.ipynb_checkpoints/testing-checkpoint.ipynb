# %%
# !pip install librosa
# !pip install pretty_midi
# Out:
# Requirement already satisfied: librosa in c:\users\yuanx\anaconda3\lib\site-packages (0.9.1)
# Requirement already satisfied: scikit-learn>=0.19.1 in c:\users\yuanx\anaconda3\lib\site-packages (from librosa) (0.24.2)
# Requirement already satisfied: packaging>=20.0 in c:\users\yuanx\anaconda3\lib\site-packages (from librosa) (20.4)
# Requirement already satisfied: numba>=0.45.1 in c:\users\yuanx\anaconda3\lib\site-packages (from librosa) (0.51.2)
# Requirement already satisfied: scipy>=1.2.0 in c:\users\yuanx\anaconda3\lib\site-packages (from librosa) (1.5.2)
# Requirement already satisfied: pooch>=1.0 in c:\users\yuanx\anaconda3\lib\site-packages (from librosa) (1.6.0)
# Requirement already satisfied: numpy>=1.17.0 in c:\users\yuanx\anaconda3\lib\site-packages (from librosa) (1.22.3)
# Requirement already satisfied: soundfile>=0.10.2 in c:\users\yuanx\anaconda3\lib\site-packages (from librosa) (0.10.3.post1)
# Requirement already satisfied: decorator>=4.0.10 in c:\users\yuanx\anaconda3\lib\site-packages (from librosa) (4.4.2)
# Requirement already satisfied: audioread>=2.1.5 in c:\users\yuanx\anaconda3\lib\site-packages (from librosa) (2.1.9)
# Requirement already satisfied: joblib>=0.14 in c:\users\yuanx\anaconda3\lib\site-packages (from librosa) (1.1.0)
# Requirement already satisfied: resampy>=0.2.2 in c:\users\yuanx\anaconda3\lib\site-packages (from librosa) (0.2.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\yuanx\anaconda3\lib\site-packages (from scikit-learn>=0.19.1->librosa) (2.1.0)
# Requirement already satisfied: six in c:\users\yuanx\appdata\roaming\python\python38\site-packages (from packaging>=20.0->librosa) (1.15.0)
# Requirement already satisfied: pyparsing>=2.0.2 in c:\users\yuanx\anaconda3\lib\site-packages (from packaging>=20.0->librosa) (2.4.7)
# Requirement already satisfied: llvmlite<0.35,>=0.34.0.dev0 in c:\users\yuanx\anaconda3\lib\site-packages (from numba>=0.45.1->librosa) (0.34.0)
# Requirement already satisfied: setuptools in c:\users\yuanx\anaconda3\lib\site-packages (from numba>=0.45.1->librosa) (50.3.1.post20201107)
# Requirement already satisfied: requests>=2.19.0 in c:\users\yuanx\anaconda3\lib\site-packages (from pooch>=1.0->librosa) (2.24.0)
# Requirement already satisfied: appdirs>=1.3.0 in c:\users\yuanx\anaconda3\lib\site-packages (from pooch>=1.0->librosa) (1.4.4)
# Requirement already satisfied: cffi>=1.0 in c:\users\yuanx\anaconda3\lib\site-packages (from soundfile>=0.10.2->librosa) (1.14.3)
# Requirement already satisfied: idna<3,>=2.5 in c:\users\yuanx\anaconda3\lib\site-packages (from requests>=2.19.0->pooch>=1.0->librosa) (2.10)
# Requirement already satisfied: chardet<4,>=3.0.2 in c:\users\yuanx\anaconda3\lib\site-packages (from requests>=2.19.0->pooch>=1.0->librosa) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\yuanx\anaconda3\lib\site-packages (from requests>=2.19.0->pooch>=1.0->librosa) (2020.6.20)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in c:\users\yuanx\anaconda3\lib\site-packages (from requests>=2.19.0->pooch>=1.0->librosa) (1.25.11)
# Requirement already satisfied: pycparser in c:\users\yuanx\anaconda3\lib\site-packages (from cffi>=1.0->soundfile>=0.10.2->librosa) (2.20)
# Requirement already satisfied: pretty_midi in c:\users\yuanx\anaconda3\lib\site-packages (0.2.9)
# Requirement already satisfied: six in c:\users\yuanx\appdata\roaming\python\python38\site-packages (from pretty_midi) (1.15.0)
# Requirement already satisfied: numpy>=1.7.0 in c:\users\yuanx\anaconda3\lib\site-packages (from pretty_midi) (1.22.3)
# Requirement already satisfied: mido>=1.1.16 in c:\users\yuanx\anaconda3\lib\site-packages (from pretty_midi) (1.2.10)

# %%
import librosa, librosa.display

import numpy as np
import matplotlib.pyplot as plt

import IPython.display as ipd

from utils import *

from torch.nn import Transformer
from torch.autograd import Variable
from torch.nn.functional import conv1d, mse_loss
import torch

# %load_ext autoreload
# %autoreload 2

# %%
def estimate_pitch(segment, sr, fmin=50.0, fmax=2000.0):
    
    # Compute autocorrelation of input segment.
    r = librosa.autocorrelate(segment)
    
    # Define lower and upper limits for the autocorrelation argmax.
    i_min = sr/fmax
    i_max = sr/fmin
    r[:int(i_min)] = 0
    r[int(i_max):] = 0
    
    # Find the location of the maximum autocorrelation.
    i = r.argmax()
    f0 = float(sr)/i
    return f0

def generate_sine(f0, sr, n_duration):
    n = np.arange(n_duration)
    return 0.2*np.sin(2*np.pi*f0*n/float(sr))

def estimate_pitch_and_generate_sine(x, onset_samples, i, sr):
    n0 = onset_samples[i]
    n1 = onset_samples[i+1]
    f0 = estimate_pitch(x[n0:n1], sr)
    return generate_sine(f0, sr, n1-n0)

# %%
# Librosa method of generating sheet music
filename = "data/01_Jupiter_vn_vc/AuSep_1_vn_01_Jupiter.wav"
audio, rate = librosa.load("../../" + filename, mono = True)

audio = np.hstack([[0], audio])

C = np.abs(librosa.cqt(audio))

fig, ax = plt.subplots(2, 1, figsize = (10, 8), sharex = True)
librosa.display.specshow(librosa.amplitude_to_db(C, ref = np.max), ax = ax[0], sr=rate, x_axis='time', y_axis='cqt_note')

onset_boundaries = librosa.onset.onset_detect(
    audio,
    sr=rate, units='samples', 
    backtrack = False,
)

y = np.concatenate([
    estimate_pitch_and_generate_sine(audio, onset_boundaries, i, sr=rate)
    for i in range(len(onset_boundaries)-1)
])

actlProb_threshold = 0.5
C = np.abs(librosa.cqt(y))
C = (C - C.min()) / (C.max() - C.min())
C = np.apply_along_axis(lambda x: ((x == x.max()) & (x > actlProb_threshold)), axis=1, arr=C.T)
librosa.display.specshow(C.T, ax = ax[1], sr=rate, x_axis='time', y_axis='cqt_note')

# %%
C.shape

# %%
ipd.Audio(y, rate = rate)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
midi = createMIDI(song = y, rate = rate, instrument = "Violin", actlProb = C, actlProb_threshold = 0.9)
librosa.display.specshow(C.T, sr=rate, x_axis='time', y_axis='cqt_note')
# Out:
# c:\Users\yuanx\Documents\GitHub\music-decomp\AI\Sheet Music\sheet_music_model.py:31: FutureWarning: Pass y=[0.00000000e+00 1.56918191e-02 3.12868930e-02 ... 1.08128163e-01
#  5.63465114e-02 1.04059610e-13], sr=22050 as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   midi = pm.PrettyMIDI(initial_tempo=librosa.beat.tempo(song, rate).mean())
# c:\Users\yuanx\Documents\GitHub\music-decomp\AI\Sheet Music\sheet_music_model.py:13: FutureWarning: Pass y=[0.00000000e+00 1.56918191e-02 3.12868930e-02 ... 1.08128163e-01
#  5.63465114e-02 1.04059610e-13], sr=22050 as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   chroma = librosa.feature.chroma_cqt(song, rate).sum(1)
# c:\Users\yuanx\Documents\GitHub\music-decomp\AI\Sheet Music\sheet_music_model.py:43: FutureWarning: Pass sr=22050 as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   intervals, frameLenSecs = {}, librosa.frames_to_time(1, rate) # Time is in absolute seconds, not relative MIDI ticks

# %%
midi.write("./testing.mid")
