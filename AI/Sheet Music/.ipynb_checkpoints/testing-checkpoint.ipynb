# %%
# !pip install librosa
# !pip install pretty_midi
# Out:
# Requirement already satisfied: mido in c:\users\yuanx\anaconda3\lib\site-packages (1.2.10)
# Requirement already satisfied: librosa in c:\users\yuanx\anaconda3\lib\site-packages (0.9.1)
# Requirement already satisfied: decorator>=4.0.10 in c:\users\yuanx\anaconda3\lib\site-packages (from librosa) (4.4.2)
# Requirement already satisfied: numba>=0.45.1 in c:\users\yuanx\anaconda3\lib\site-packages (from librosa) (0.51.2)
# Requirement already satisfied: pooch>=1.0 in c:\users\yuanx\anaconda3\lib\site-packages (from librosa) (1.6.0)
# Requirement already satisfied: scipy>=1.2.0 in c:\users\yuanx\anaconda3\lib\site-packages (from librosa) (1.5.2)
# Requirement already satisfied: scikit-learn>=0.19.1 in c:\users\yuanx\anaconda3\lib\site-packages (from librosa) (0.24.2)
# Requirement already satisfied: audioread>=2.1.5 in c:\users\yuanx\anaconda3\lib\site-packages (from librosa) (2.1.9)
# Requirement already satisfied: soundfile>=0.10.2 in c:\users\yuanx\anaconda3\lib\site-packages (from librosa) (0.10.3.post1)
# Requirement already satisfied: joblib>=0.14 in c:\users\yuanx\anaconda3\lib\site-packages (from librosa) (0.17.0)
# Requirement already satisfied: packaging>=20.0 in c:\users\yuanx\anaconda3\lib\site-packages (from librosa) (20.4)
# Requirement already satisfied: resampy>=0.2.2 in c:\users\yuanx\anaconda3\lib\site-packages (from librosa) (0.2.2)
# Requirement already satisfied: numpy>=1.17.0 in c:\users\yuanx\anaconda3\lib\site-packages (from librosa) (1.19.2)
# Requirement already satisfied: llvmlite<0.35,>=0.34.0.dev0 in c:\users\yuanx\anaconda3\lib\site-packages (from numba>=0.45.1->librosa) (0.34.0)
# Requirement already satisfied: setuptools in c:\users\yuanx\anaconda3\lib\site-packages (from numba>=0.45.1->librosa) (50.3.1.post20201107)
# Requirement already satisfied: requests>=2.19.0 in c:\users\yuanx\anaconda3\lib\site-packages (from pooch>=1.0->librosa) (2.24.0)
# Requirement already satisfied: appdirs>=1.3.0 in c:\users\yuanx\anaconda3\lib\site-packages (from pooch>=1.0->librosa) (1.4.4)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\yuanx\anaconda3\lib\site-packages (from scikit-learn>=0.19.1->librosa) (2.1.0)
# Requirement already satisfied: cffi>=1.0 in c:\users\yuanx\anaconda3\lib\site-packages (from soundfile>=0.10.2->librosa) (1.14.3)
# Requirement already satisfied: six in c:\users\yuanx\anaconda3\lib\site-packages (from packaging>=20.0->librosa) (1.15.0)
# Requirement already satisfied: pyparsing>=2.0.2 in c:\users\yuanx\anaconda3\lib\site-packages (from packaging>=20.0->librosa) (2.4.7)
# Requirement already satisfied: chardet<4,>=3.0.2 in c:\users\yuanx\anaconda3\lib\site-packages (from requests>=2.19.0->pooch>=1.0->librosa) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\yuanx\anaconda3\lib\site-packages (from requests>=2.19.0->pooch>=1.0->librosa) (2020.6.20)
# Requirement already satisfied: idna<3,>=2.5 in c:\users\yuanx\anaconda3\lib\site-packages (from requests>=2.19.0->pooch>=1.0->librosa) (2.10)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in c:\users\yuanx\anaconda3\lib\site-packages (from requests>=2.19.0->pooch>=1.0->librosa) (1.25.11)
# Requirement already satisfied: pycparser in c:\users\yuanx\anaconda3\lib\site-packages (from cffi>=1.0->soundfile>=0.10.2->librosa) (2.20)
# Requirement already satisfied: data in c:\users\yuanx\anaconda3\lib\site-packages (0.4)
# Requirement already satisfied: six in c:\users\yuanx\anaconda3\lib\site-packages (from data) (1.15.0)
# Requirement already satisfied: funcsigs in c:\users\yuanx\anaconda3\lib\site-packages (from data) (1.0.2)
# Requirement already satisfied: decorator in c:\users\yuanx\anaconda3\lib\site-packages (from data) (4.4.2)
# Collecting torch
#   Downloading torch-1.11.0-cp38-cp38-win_amd64.whl (158.0 MB)
# Requirement already satisfied: typing-extensions in c:\users\yuanx\anaconda3\lib\site-packages (from torch) (3.7.4.3)
# Installing collected packages: torch
# Successfully installed torch-1.11.0
# Collecting musicnet
#   Downloading musicnet-1.1.2-py3-none-any.whl (1.9 kB)
# Collecting ipython>=7.24.1
#   Downloading ipython-8.2.0-py3-none-any.whl (750 kB)
# Collecting joblib>=1.0.1
#   Downloading joblib-1.1.0-py2.py3-none-any.whl (306 kB)
# Collecting numpy>=1.19.5
#   Downloading numpy-1.22.3-cp38-cp38-win_amd64.whl (14.7 MB)
# Requirement already satisfied: scikit-learn>=0.23.2 in c:\users\yuanx\anaconda3\lib\site-packages (from musicnet) (0.24.2)
# Requirement already satisfied: librosa>=0.8.1 in c:\users\yuanx\anaconda3\lib\site-packages (from musicnet) (0.9.1)
# Requirement already satisfied: pandas>=1.2.4 in c:\users\yuanx\anaconda3\lib\site-packages (from musicnet) (1.2.5)
# Requirement already satisfied: colorama; sys_platform == "win32" in c:\users\yuanx\anaconda3\lib\site-packages (from ipython>=7.24.1->musicnet) (0.4.4)
# Requirement already satisfied: backcall in c:\users\yuanx\anaconda3\lib\site-packages (from ipython>=7.24.1->musicnet) (0.2.0)
# Requirement already satisfied: decorator in c:\users\yuanx\anaconda3\lib\site-packages (from ipython>=7.24.1->musicnet) (4.4.2)
# Requirement already satisfied: traitlets>=5 in c:\users\yuanx\anaconda3\lib\site-packages (from ipython>=7.24.1->musicnet) (5.0.5)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in c:\users\yuanx\anaconda3\lib\site-packages (from ipython>=7.24.1->musicnet) (3.0.8)
# Requirement already satisfied: jedi>=0.16 in c:\users\yuanx\anaconda3\lib\site-packages (from ipython>=7.24.1->musicnet) (0.17.1)
# Requirement already satisfied: pickleshare in c:\users\yuanx\anaconda3\lib\site-packages (from ipython>=7.24.1->musicnet) (0.7.5)
# Collecting stack-data
#   Downloading stack_data-0.2.0-py3-none-any.whl (21 kB)
# Requirement already satisfied: pygments>=2.4.0 in c:\users\yuanx\anaconda3\lib\site-packages (from ipython>=7.24.1->musicnet) (2.7.2)
# Requirement already satisfied: setuptools>=18.5 in c:\users\yuanx\anaconda3\lib\site-packages (from ipython>=7.24.1->musicnet) (50.3.1.post20201107)
# Collecting matplotlib-inline
#   Downloading matplotlib_inline-0.1.3-py3-none-any.whl (8.2 kB)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\yuanx\anaconda3\lib\site-packages (from scikit-learn>=0.23.2->musicnet) (2.1.0)
# Requirement already satisfied: scipy>=0.19.1 in c:\users\yuanx\anaconda3\lib\site-packages (from scikit-learn>=0.23.2->musicnet) (1.5.2)
# Requirement already satisfied: resampy>=0.2.2 in c:\users\yuanx\anaconda3\lib\site-packages (from librosa>=0.8.1->musicnet) (0.2.2)
# Requirement already satisfied: numba>=0.45.1 in c:\users\yuanx\anaconda3\lib\site-packages (from librosa>=0.8.1->musicnet) (0.51.2)
# Requirement already satisfied: soundfile>=0.10.2 in c:\users\yuanx\anaconda3\lib\site-packages (from librosa>=0.8.1->musicnet) (0.10.3.post1)
# Requirement already satisfied: audioread>=2.1.5 in c:\users\yuanx\anaconda3\lib\site-packages (from librosa>=0.8.1->musicnet) (2.1.9)
# Requirement already satisfied: pooch>=1.0 in c:\users\yuanx\anaconda3\lib\site-packages (from librosa>=0.8.1->musicnet) (1.6.0)
# Requirement already satisfied: packaging>=20.0 in c:\users\yuanx\anaconda3\lib\site-packages (from librosa>=0.8.1->musicnet) (20.4)
# Requirement already satisfied: pytz>=2017.3 in c:\users\yuanx\anaconda3\lib\site-packages (from pandas>=1.2.4->musicnet) (2020.1)
# Requirement already satisfied: python-dateutil>=2.7.3 in c:\users\yuanx\anaconda3\lib\site-packages (from pandas>=1.2.4->musicnet) (2.8.1)
# Requirement already satisfied: ipython-genutils in c:\users\yuanx\anaconda3\lib\site-packages (from traitlets>=5->ipython>=7.24.1->musicnet) (0.2.0)
# Requirement already satisfied: wcwidth in c:\users\yuanx\anaconda3\lib\site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=7.24.1->musicnet) (0.2.5)
# Requirement already satisfied: parso<0.8.0,>=0.7.0 in c:\users\yuanx\anaconda3\lib\site-packages (from jedi>=0.16->ipython>=7.24.1->musicnet) (0.7.0)
# Collecting pure-eval
#   Downloading pure_eval-0.2.2-py3-none-any.whl (11 kB)
# Collecting executing
#   Downloading executing-0.8.3-py2.py3-none-any.whl (16 kB)
# Collecting asttokens
#   Downloading asttokens-2.0.5-py2.py3-none-any.whl (20 kB)
# Requirement already satisfied: six>=1.3 in c:\users\yuanx\anaconda3\lib\site-packages (from resampy>=0.2.2->librosa>=0.8.1->musicnet) (1.15.0)
# Requirement already satisfied: llvmlite<0.35,>=0.34.0.dev0 in c:\users\yuanx\anaconda3\lib\site-packages (from numba>=0.45.1->librosa>=0.8.1->musicnet) (0.34.0)
# Requirement already satisfied: cffi>=1.0 in c:\users\yuanx\anaconda3\lib\site-packages (from soundfile>=0.10.2->librosa>=0.8.1->musicnet) (1.14.3)
# Requirement already satisfied: requests>=2.19.0 in c:\users\yuanx\anaconda3\lib\site-packages (from pooch>=1.0->librosa>=0.8.1->musicnet) (2.24.0)
# Requirement already satisfied: appdirs>=1.3.0 in c:\users\yuanx\anaconda3\lib\site-packages (from pooch>=1.0->librosa>=0.8.1->musicnet) (1.4.4)
# Requirement already satisfied: pyparsing>=2.0.2 in c:\users\yuanx\anaconda3\lib\site-packages (from packaging>=20.0->librosa>=0.8.1->musicnet) (2.4.7)
# Requirement already satisfied: pycparser in c:\users\yuanx\anaconda3\lib\site-packages (from cffi>=1.0->soundfile>=0.10.2->librosa>=0.8.1->musicnet) (2.20)
# Requirement already satisfied: chardet<4,>=3.0.2 in c:\users\yuanx\anaconda3\lib\site-packages (from requests>=2.19.0->pooch>=1.0->librosa>=0.8.1->musicnet) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\yuanx\anaconda3\lib\site-packages (from requests>=2.19.0->pooch>=1.0->librosa>=0.8.1->musicnet) (2020.6.20)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in c:\users\yuanx\anaconda3\lib\site-packages (from requests>=2.19.0->pooch>=1.0->librosa>=0.8.1->musicnet) (1.25.11)
# Requirement already satisfied: idna<3,>=2.5 in c:\users\yuanx\anaconda3\lib\site-packages (from requests>=2.19.0->pooch>=1.0->librosa>=0.8.1->musicnet) (2.10)
# Installing collected packages: pure-eval, executing, asttokens, stack-data, matplotlib-inline, ipython, joblib, numpy, musicnet
#   Attempting uninstall: ipython
#     Found existing installation: ipython 7.19.0
#     Uninstalling ipython-7.19.0:
#       Successfully uninstalled ipython-7.19.0
#   Attempting uninstall: joblib
#     Found existing installation: joblib 0.17.0
#     Uninstalling joblib-0.17.0:
#       Successfully uninstalled joblib-0.17.0
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.19.2
#     Uninstalling numpy-1.19.2:
#       Successfully uninstalled numpy-1.19.2
# Successfully installed asttokens-2.0.5 executing-0.8.3 ipython-8.2.0 joblib-1.1.0 matplotlib-inline-0.1.3 musicnet-1.1.2 numpy-1.22.3 pure-eval-0.2.2 stack-data-0.2.0
# ERROR: After October 2020 you may experience errors when installing or updating packages. This is because pip will change the way that it resolves dependency conflicts.
#
# We recommend you use --use-feature=2020-resolver to test your packages with the new resolver before it becomes the default.
#
# spyder 4.1.5 requires pyqt5<5.13; python_version >= "3", which is not installed.
# spyder 4.1.5 requires pyqtwebengine<5.13; python_version >= "3", which is not installed.
# ipykernel 6.4.1 requires ipython<8.0,>=7.23.1, but you'll have ipython 8.2.0 which is incompatible.

# %%
import librosa, librosa.display

import numpy as np
import matplotlib.pyplot as plt

import IPython.display as ipd

from sheet_music_model import *

from torch.nn import Transformer
from torch.autograd import Variable
from torch.nn.functional import conv1d, mse_loss
import torch

# %load_ext autoreload
# %autoreload 2

# %%
def estimate_pitch(segment, sr, fmin=50.0, fmax=2000.0):
    
    # Compute autocorrelation of input segment.
    r = librosa.autocorrelate(segment)
    
    # Define lower and upper limits for the autocorrelation argmax.
    i_min = sr/fmax
    i_max = sr/fmin
    r[:int(i_min)] = 0
    r[int(i_max):] = 0
    
    # Find the location of the maximum autocorrelation.
    i = r.argmax()
    f0 = float(sr)/i
    return f0

def generate_sine(f0, sr, n_duration):
    n = np.arange(n_duration)
    return 0.2*np.sin(2*np.pi*f0*n/float(sr))

def estimate_pitch_and_generate_sine(x, onset_samples, i, sr):
    n0 = onset_samples[i]
    n1 = onset_samples[i+1]
    f0 = estimate_pitch(x[n0:n1], sr)
    return generate_sine(f0, sr, n1-n0)

# %%
# Librosa method of generating sheet music
filename = "data/01_Jupiter_vn_vc/AuSep_2_vc_01_Jupiter.wav"
audio, rate = librosa.load("../../" + filename, mono = True)

audio = np.hstack([[0], audio])

C = np.abs(librosa.cqt(audio))

fig, ax = plt.subplots(2, 1, figsize = (20, 8), sharex = True)
librosa.display.specshow(librosa.amplitude_to_db(C, ref = np.max), ax = ax[0], sr=rate, x_axis='time', y_axis='cqt_note')

onset_boundaries = librosa.onset.onset_detect(
    audio,
    sr=rate, units='samples', 
    backtrack = False,
)

print(onset_boundaries)

# y = np.concatenate([
#     estimate_pitch_and_generate_sine(audio, onset_boundaries, i, sr=rate)
#     for i in range(len(onset_boundaries)-1)
# ])
# print(y)
# librosa.display.specshow(abs(y), sr=rate, x_axis='time', y_axis='cqt_note')
# plt.figure(figsize = (20, 8))
# librosa.display.waveshow(audio, sr=rate, ax = ax[1])
# plt.vlines(onset_boundaries, -.25, .25, color='r')

y = np.concatenate([
    estimate_pitch_and_generate_sine(audio, onset_boundaries, i, sr=rate)
    for i in range(len(onset_boundaries)-1)
])

librosa.display.specshow(abs(librosa.cqt(y, sr = rate)), ax = ax[1], sr=rate, x_axis='time', y_axis='cqt_note')

# getKey(audio, rate)
ipd.Audio(y, rate = rate)
# Out:
# C:\Users\yuanx\AppData\Local\Temp/ipykernel_18596/1264980905.py:12: FutureWarning: Pass y=[ 0.         -0.00104751 -0.00158909 ... -0.00333745 -0.00329139
#   0.        ] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   onset_boundaries = librosa.onset.onset_detect(
# [ 125952  137728  142336  146432  150528  154624  159232  160256  164864
#   167936  175104  179200  180736  187904  189440  195584  199168  202752
#   206848  210944  215040  216064  222720  227328  233472  238592  243712
#   246784  248832  250880  252928  256512  259072  260608  264704  269824
#   275456  281600  284672  288768  289792  295424  296960  299008  302080
#   305664  309760  313344  316928  320512  324096  328192  331264  334848
#   342528  344064  350720  352256  354304  356352  359936  361984  364032
#   366080  368128  375808  376832  379904  382976  386560  390656  392192
#   393216  396288  398848  401408  408576  412672  416768  422400  427008
#   428544  432128  436736  441856  444416  445952  451072  454144  455168
#   459264  462848  466944  479744  483840  486912  504320  510976  516096
#   522240  525312  528896  532480  539136  542720  544768  547328  551936
#   556544  561664  566272  568320  570368  572416  576512  584704  588800
#   590848  592384  594432  601600  606208  608256  609792  611840  615936
#   617472  621568  623616  625664  627200  633856  635392  640000  642560
#   646656  651776  653312  656896  658432  661504  664576  666624  668672
#   672768  674816  678912  684032  686080  694272  697856  700416  704512
#   708096  711168  715776  718848  724992  726016  730112  733696  738304
#   743424  750080  751104  753664  756224  760320  763392  766976  769536
#   773120  774656  776704  780288  784384  788480  793088  797184  800256
#   804864  807936  812032  816640  818176  821248  825344  832512  834560
#   836608  843264  848384  851456  854528  856576  858624  862720  866816
#   868352  871936  875008  879104  882176  883200  885760  888320  889344
#   891392  898048  905728  908800  912384  915968  916992  920576  922624
#   926208  929792  933888  935424  939520  943616  947200  950784  959488
#   970240  983552  994816  996864  998912 1000960 1006080 1008128 1011712
#  1015808 1019904 1024512 1028608 1030144 1031680 1035264 1047552 1054208
#  1057280 1059328 1063424 1064960 1067520 1073664 1076736 1078272 1082880
#  1084928 1089024 1092608 1096192 1097216 1103360 1106944 1111040 1114624
#  1118720 1122816 1126400 1129472 1134592 1136640 1140224 1144320 1147392
#  1148928 1152512 1156608 1159680 1162240 1164288 1168384 1172480 1176576
#  1179648 1186304 1190400 1195520 1197056 1200128 1207296 1208832 1212928
#  1217536 1221632 1226752 1231360 1234432 1238528 1242624 1244160 1251328
#  1255424 1259520 1261568 1263104 1267200 1271296 1274368 1278464 1285632
#  1288704 1292288 1295872 1297408 1299968 1302016 1311744 1315840 1319936
#  1324032 1329664 1332224 1358336 1361920 1366016 1369600 1377280 1380352]
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
